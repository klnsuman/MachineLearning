# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./data/concrete_data.csv')

# %%
X = data.iloc[:,:8].values
y = data.iloc[:,8].values.reshape(-1,1)

# %%
print(np.shape(X))
print(np.shape(y))
# Out:
# (1030, 8)
# (1030, 1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,y_test = train_test_split(X,y,test_size=.2,random_state=2021)

# %%
#!pip install xgboost
# !brew install libomp
# Out:
# Updating Homebrew...
# ==> Auto-updated Homebrew!
# Updated Homebrew from d45832bbf to 4d5af4066.
# Updated 4 taps (homebrew/core, homebrew/cask, homebrew/services and mongodb/brew).
# ==> New Formulae
# abricate                                 locust
# actionlint                               lunzip
# age                                      lziprecover
# airspyhf                                 macos-term-size
# alda                                     mailcatcher
# alembic                                  mariadb@10.5
# alerter                                  marp-cli
# amfora                                   mathlibtools
# ansilove                                 matterbridge
# apache-pulsar                            maturin
# apt                                      mbedtls@2
# argocd-autopilot                         microsocks
# argocd-vault-plugin                      mimalloc
# artillery                                moar
# ...

# %%
from xgboost import XGBRegressor
xgb_model = XGBRegressor(random_statue=2021)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-13-79383736c173> in <module>
# ----> 1 from xgboost import XGBRegressor
#       2 xgb_model = XGBRegressor(random_statue=2021)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xgboost/__init__.py in <module>
#       7 import os
#       8
# ----> 9 from .core import DMatrix, DeviceQuantileDMatrix, Booster
#      10 from .training import train, cv
#      11 from . import rabit  # noqa
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py in <module>
#     193
#     194 # load the XGBoost library globally
# --> 195 _LIB = _load_lib()
#     196
#     197
#
# ~/opt/anaconda3/lib/python3.8/site-packages/xgboost/core.py in _load_lib()
#     176     if not lib_success:
#     177         libname = os.path.basename(lib_paths[0])
# --> 178         raise XGBoostError(
# ...

# %%
search_space = {
    "n_estimators":[100,200,500],
    "max_depth":[3,6,9],
    "gamma" : [0.01,0.1],
    "learning_rate" : [0.001,0.01,0.1,1]
}

# %%
from sklearn.model_selection impport GridSearchCV

gs. = GridSerachCV(estimator=xgb_model,param_grid = search_space,
                  scoring=["r2","net_root_mean_squared_erro"],
                  refit = "r2",
                  cv=5,)
